# %% [markdown]
# # LightGBM with RNAlight hyperparameters
# lncRNA.
# CoLab L4.
# Model = LG2 (optimized parameters)
# In RNAlight, 1=nuclear.

# %%
import time
from datetime import datetime
print(datetime.now())
# Out:
# 2024-06-04 14:52:20.778399

# %%
import os
import copy
import random
import collections
import itertools
import numpy as np
import pandas as pd
#import lightgbm as lgb
import warnings
from sklearn import svm
#from sklearn.externals import joblib
import joblib
#from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split,RandomizedSearchCV
#import sklearn.metrics as metrics
# from sklearn.linear_model import LogisticRegression
import lightgbm
print('Done')
# Out:
# Done

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
print('Done')
# Out:
# Done

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    print('Running on CoLab')
    PATH='/content/drive/'
    drive.mount(PATH)
    DATA_DIR=PATH+'My Drive/data/Localization/RNAlight/'  # must end in "/"
    MODEL_DIR=PATH+'My Drive/data/Localization/RNAlight/'  # must end in "/"
    output_dir=PATH+'My Drive/data/Localization/RNAlight/'
except:
    IN_COLAB = False
    DATA_DIR = './'    # Mac
    MODEL_DIR = './'    # Mac
    output_dir = './'
print('DATA DIR', DATA_DIR)
# Out:
# Running on CoLab
# Mounted at /content/drive/
# DATA DIR /content/drive/My Drive/data/Localization/RNAlight/

# %%
SEED = 100
random.seed(SEED)
np.random.seed(SEED)
print(SEED)
# Out:
# 100

# %%
def build_model():
    new_model = lightgbm.LGBMClassifier(
        boosting_type='gbdt',
        class_weight=None,
        colsample_bytree=0.5,
        importance_type='split',
        learning_rate=0.01,
        max_depth=40,
        min_child_samples=9,
        min_child_weight=0.001,
        min_split_gain=0.0,
        n_estimators=2200,
        n_jobs=1,
        num_leaves=35,
        objective='binary',
        random_state=100,
        reg_alpha=0.005,
        reg_lambda=0,
        subsample=0.6,
        subsample_for_bin=200000,
        subsample_freq=1,
        metric='binary_logloss'
    )
    return new_model

# %%
test = build_model()
print(test)
test = None
# Out:
# LGBMClassifier(colsample_bytree=0.5, learning_rate=0.01, max_depth=40,
#                metric='binary_logloss', min_child_samples=9, n_estimators=2200,
#                n_jobs=1, num_leaves=35, objective='binary', random_state=100,
#                reg_alpha=0.005, reg_lambda=0, subsample=0.6, subsample_freq=1)

# %%
class stats_collector:
    def __init__(self):
        self.reset_statistics()
    def reset_statistics(self):
        self.cv_accuracy=[]
        self.cv_precision=[]
        self.cv_recall=[]
        self.cv_f1=[]
        self.cv_mcc=[]
        self.cv_auprc=[]
        self.cv_auroc=[]
    def _append_statistics(self,accuracy,precision,recall,f1,mcc,auprc,auroc):
        self.cv_accuracy.append(accuracy)
        self.cv_precision.append(precision)
        self.cv_recall.append(recall)
        self.cv_f1.append(f1)
        self.cv_mcc.append(mcc)
        self.cv_auprc.append(auprc)
        self.cv_auroc.append(auroc)
    def compute_performance(self,y_test,yhat_pred,yhat_classes,verbose=False):
        accuracy = accuracy_score(y_test, yhat_classes)*100.
        precision = precision_score(y_test, yhat_classes)*100.
        recall = recall_score(y_test, yhat_classes)*100.
        f1 = f1_score(y_test, yhat_classes)*100.
        mcc = matthews_corrcoef(y_test, yhat_classes)
        prc_Y, prc_X, prc_bins = precision_recall_curve(y_test, yhat_pred)
        auprc = auc(prc_X,prc_Y)*100.
        auroc = roc_auc_score(y_test, yhat_pred)*100.
        self._append_statistics(accuracy,precision,recall,f1,mcc,auprc,auroc)
        if verbose:
            self._show_confusion(y_test,yhat_pred,yhat_classes)
            self._show_statistics(accuracy,precision,recall,f1,mcc,auprc,auroc)
    def _show_confusion(self,y_test,yhat_pred,yhat_classes):
            print('Distrib of scores:',np.mean(yhat_pred),'mean',np.std(yhat_pred),'std')
            print('Range of scores:',np.min(yhat_pred),'to',np.max(yhat_pred))
            cm1 = confusion_matrix(y_test,yhat_classes)
            print('Confusion matrix\n',cm1)
            cm2 = confusion_matrix(y_test,yhat_classes,normalize='all')
            print('Normalized matrix\n',cm2)
    def _show_statistics(self,accuracy,precision,recall,f1,mcc,auprc,auroc):
            print('accuracy:',accuracy,'precision:',precision,'recall:',recall,\
                  'F1:',f1,'MCC:',mcc,'AUPRC:',auprc,'AUROC:',auroc)
    def _show_variance(self, name, stats_list):
        if name=='MCC':
            print('%10s %5.3f mean, %6.3f stdev' % (name,np.mean(stats_list),np.std(stats_list) ) )
        else:
            print('%10s %5.2f mean, %6.3f stdev' % (name,np.mean(stats_list),np.std(stats_list) ) )
        print(stats_list)
    def dump_all(self):
        self._show_variance('accuracy', self.cv_accuracy)
        self._show_variance('precision',self.cv_precision)
        self._show_variance('recall',   self.cv_recall)
        self._show_variance('F1',       self.cv_f1)
        self._show_variance('MCC',      self.cv_mcc)
        self._show_variance('AUPRC',    self.cv_auprc)
        self._show_variance('AUROC',    self.cv_auroc)

# %%
# From RNAlight notebook
def _count_kmer(Dataset,k): # k = 3,4,5

    # copy dataset
    dataset = copy.deepcopy(Dataset)
    # alphbet of nucleotide
    nucleotide = ['A','C','G','T']

    # generate k-mers
    #  k == 5:
    five = list(itertools.product(nucleotide,repeat=5))
    pentamer = []
    for n in five:
        pentamer.append("".join(n))

    #  k == 4:
    four = list(itertools.product(nucleotide,repeat=4))
    tetramer = []
    for n in four:
        tetramer.append("".join(n))

    # k == 3:
    three = list(itertools.product(nucleotide,repeat=3))
    threemer = []
    for n in three:
        threemer.append("".join(n))

    # input features can be combinations of diffrent k values
    if k == 34:
        table_kmer = dict.fromkeys(threemer,0)
        table_kmer.update(dict.fromkeys(tetramer,0))
    if k == 45:
        table_kmer = dict.fromkeys(tetramer,0)
        table_kmer.update(dict.fromkeys(pentamer,0))
    if k == 345:
        table_kmer = dict.fromkeys(threemer,0)
        table_kmer.update(dict.fromkeys(tetramer,0))
        table_kmer.update(dict.fromkeys(pentamer,0))

    # count k-mer for each sequence
    for mer in table_kmer.keys():
        table_kmer[mer] = dataset["cdna"].apply(lambda x : x.count(mer))

    # for k-mer raw count without normalization, index: nuc:1 or cyto:0
    rawcount_kmer_df = pd.DataFrame(table_kmer)
    df1_rawcount = pd.concat([rawcount_kmer_df,dataset["ensembl_transcript_id"]],axis = 1)
    df1_rawcount.index = dataset["tag"]

    # for k-mer frequency with normalization , index: nuc:1 or cyto:0
    freq_kmer_df = rawcount_kmer_df.apply(lambda x: x/x.sum(),axis=1)
    df1 = pd.concat([freq_kmer_df,dataset["ensembl_transcript_id"]],axis = 1)
    df1.index = dataset["tag"]

    return df1  # ,df1_rawcount

# %%
# From RNAlight notebook
def load_dataframe(cyto_f,nuc_f):
    print('load dataframe')
    dataset_cyto = pd.read_csv(cyto_f,sep='\t',index_col = False)    #1806
    dataset_nuc = pd.read_csv(nuc_f,sep='\t',index_col = False)    #1986
    print( len(dataset_cyto), 'cytoplasmic samples')
    print( len(dataset_nuc),  'nuclear samples')
    return dataset_cyto,dataset_nuc

# %%
# Added
def rebalance(dataset_cyto,dataset_nuc):
    print('sample down to balance classes')
    min_size = min(len(dataset_cyto),len(dataset_nuc))
    # random sampling without replacement
    dataset_cyto = dataset_cyto.sample(min_size, random_state=SEED)
    dataset_nuc  = dataset_nuc.sample(min_size,  random_state=SEED)
    print( len(dataset_cyto), 'cytoplasmic samples')
    print( len(dataset_nuc),  'nuclear samples')
    return dataset_cyto,dataset_nuc

# %%
# From RNAlight notebook
def extract_features_and_split(dataset_cyto,dataset_nuc):
    print('add labels, concatenate')
    # Set the tag of RCI(log2FC): nuclear 1 / cytosol 0
    dataset_nuc['tag'] = 1;dataset_cyto['tag'] = 0
    # merge the nuc and cyto dataset
    dataset = pd.concat([dataset_nuc,dataset_cyto]) # 3792

    print('dedupe (probably not necessary)')
    # remove duplications(actually,each lncRNA is unique in its class)
    dataset.drop_duplicates(keep="first",subset=["ensembl_transcript_id","name","cdna"],inplace=True) # 3792

    print('count kmers')
    # k = 3,4,5 count the normalized and raw count of kmer
    df_kmer_345 = _count_kmer(dataset,345)   # df_kmer_345,df_kmer_345_rawcount =

    # We commented this out. No need to save the tsv.
    # df_kmer_345.to_csv(os.path.join(output_dir,"df_kmer345_freq.tsv"),sep='\t')
    # This was commented out in the original. Seems they reran using saved kmers. Should test if file exists.
    # load kmer file
    # df_kmer_345 = pd.read_csv(os.path.join(output_dir,"df_kmer345_freq.tsv"),sep='\t',index_col= 0)

    # convert to x:kmer-freq , y:label
    del df_kmer_345['ensembl_transcript_id']
    x_kmer = df_kmer_345.values
    y_kmer = y_kmer = np.array(df_kmer_345.index)

    # split into training and test sets (9:1)
    print('train/test split')
    x_train, x_test, y_train, y_test = train_test_split(x_kmer, y_kmer, test_size = 0.1, random_state = SEED)

    #print('Apply cross-validation to all the data (no test set withheld)')
    #x_train, x_test, y_train, y_test = train_test_split(x_kmer, y_kmer, test_size = None, random_state = SEED)
    print('train set shape',x_train.shape)
    # Added
    labels,counts = np.unique(y_train,return_counts=True)
    print('train set labels', labels, 'counts',counts)
    labels,counts = np.unique(y_test,return_counts=True)
    print('test set labels', labels, 'counts',counts)
    return x_train, x_test, y_train, y_test

# %%
def do_cv(x_train, y_train):
    stats = stats_collector()
    for round in range(1,3):
        fold=0
        splitter = KFold(n_splits=5)
        for train_index, valid_index in splitter.split(x_train):
            fold += 1
            print('Round', round, 'Fold', fold)
            print('Num samples in train and valid sets:', len(train_index), len(valid_index))
            print('Train')
            lgb = build_model()
            history = lgb.fit(x_train[train_index], y_train[train_index])
            print('Validate')
            x_valid = x_train[valid_index]
            y_valid = y_train[valid_index]
            yhat_classes= lgb.predict(x_valid)  # get 0 or 1
            yhat_pairs=   lgb.predict_proba(x_valid)  # get [ prob of 0, prob of 1 ]
            yhat_pred=    [pair[1] for pair in yhat_pairs]
            stats.compute_performance(y_valid,yhat_pred,yhat_classes,verbose=False)
    return stats

# %%
if True:
    print('Use the RNAlight training set (already has middle excluded)')
    cyto_f = DATA_DIR+'02_lncRNA_info_cyto_transcript.tsv'
    nuc_f  = DATA_DIR+'02_lncRNA_info_nuc_transcript.tsv'
    print('Data files:')
    print(cyto_f,'\n',nuc_f)
    dataset_cyto,dataset_nuc = load_dataframe(cyto_f,nuc_f)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Use the RNAlight training set (already has middle excluded)
# Data files:
# /content/drive/My Drive/data/Localization/RNAlight/02_lncRNA_info_cyto_transcript.tsv
#  /content/drive/My Drive/data/Localization/RNAlight/02_lncRNA_info_nuc_transcript.tsv
# load dataframe
# 1806 cytoplasmic samples
# 1986 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (3412, 1344)
# train set labels [0 1] counts [1622 1790]
# test set labels [0 1] counts [184 196]
# Round 1 Fold 1
# Num samples in train and valid sets: 2729 683
# Train
# [LightGBM] [Info] Number of positive: 1419, number of negative: 1310
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086401 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335916
# [LightGBM] [Info] Number of data points in the train set: 2729, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.519971 -> initscore=0.079925
# [LightGBM] [Info] Start training from score 0.079925
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 2729 683
# Train
# [LightGBM] [Info] Number of positive: 1450, number of negative: 1279
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.091555 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 336303
# [LightGBM] [Info] Number of data points in the train set: 2729, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.531330 -> initscore=0.125485
# [LightGBM] [Info] Start training from score 0.125485
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 2730 682
# Train
# [LightGBM] [Info] Number of positive: 1419, number of negative: 1311
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.099094 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335875
# [LightGBM] [Info] Number of data points in the train set: 2730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.519780 -> initscore=0.079162
# [LightGBM] [Info] Start training from score 0.079162
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 2730 682
# Train
# [LightGBM] [Info] Number of positive: 1443, number of negative: 1287
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.103613 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335874
# [LightGBM] [Info] Number of data points in the train set: 2730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.528571 -> initscore=0.114410
# [LightGBM] [Info] Start training from score 0.114410
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 2730 682
# Train
# [LightGBM] [Info] Number of positive: 1429, number of negative: 1301
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.105977 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 336341
# [LightGBM] [Info] Number of data points in the train set: 2730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.523443 -> initscore=0.093842
# [LightGBM] [Info] Start training from score 0.093842
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 2729 683
# Train
# [LightGBM] [Info] Number of positive: 1419, number of negative: 1310
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026610 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 335916
# [LightGBM] [Info] Number of data points in the train set: 2729, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.519971 -> initscore=0.079925
# [LightGBM] [Info] Start training from score 0.079925
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 2729 683
# Train
# [LightGBM] [Info] Number of positive: 1450, number of negative: 1279
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.110067 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 336303
# [LightGBM] [Info] Number of data points in the train set: 2729, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.531330 -> initscore=0.125485
# [LightGBM] [Info] Start training from score 0.125485
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 2730 682
# Train
# [LightGBM] [Info] Number of positive: 1419, number of negative: 1311
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.113297 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335875
# [LightGBM] [Info] Number of data points in the train set: 2730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.519780 -> initscore=0.079162
# [LightGBM] [Info] Start training from score 0.079162
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 2730 682
# Train
# [LightGBM] [Info] Number of positive: 1443, number of negative: 1287
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.108075 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335874
# [LightGBM] [Info] Number of data points in the train set: 2730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.528571 -> initscore=0.114410
# [LightGBM] [Info] Start training from score 0.114410
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 2730 682
# Train
# [LightGBM] [Info] Number of positive: 1429, number of negative: 1301
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.106491 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 336341
# [LightGBM] [Info] Number of data points in the train set: 2730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.523443 -> initscore=0.093842
# [LightGBM] [Info] Start training from score 0.093842
# Validate
#
# Cross validation results
#   accuracy 68.05 mean,  0.647 stdev
# [68.5212298682284, 67.93557833089312, 67.00879765395894, 68.91495601173021, 67.88856304985337, 68.5212298682284, 67.93557833089312, 67.00879765395894, 68.91495601173021, 67.88856304985337]
#  precision 68.98 mean,  2.077 stdev
# [71.91011235955057, 65.63307493540051, 68.81443298969072, 68.39237057220708, 70.17045454545455, 71.91011235955057, 65.63307493540051, 68.81443298969072, 68.39237057220708, 70.17045454545455]
#     recall 71.29 mean,  2.310 stdev
# [69.00269541778977, 74.70588235294117, 71.96765498652292, 72.3342939481268, 68.42105263157895, 69.00269541778977, 74.70588235294117, 71.96765498652292, 72.3342939481268, 68.42105263157895]
#         F1 70.05 mean,  0.428 stdev
# [70.42640990371389, 69.87620357634114, 70.35573122529645, 70.30812324929971, 69.28471248246845, 70.42640990371389, 69.87620357634114, 70.35573122529645, 70.30812324929971, 69.28471248246845]
#        MCC 0.360 mean,  0.015 stdev
# [0.3684651611313505, 0.3625324582858317, 0.3325005186832103, 0.378116601260621, 0.35667860346287145, 0.3684651611313505, 0.3625324582858317, 0.3325005186832103, 0.378116601260621, 0.35667860346287145]
#      AUPRC 75.68 mean,  0.645 stdev
# [76.42080515786786, 74.56623089872897, 75.50142985021839, 76.18519304696605, 75.73782955076476, 76.42080515786786, 74.56623089872897, 75.50142985021839, 76.18519304696605, 75.73782955076476]
#      AUROC 74.53 mean,  0.963 stdev
# [74.21383647798741, 74.3568856113874, 73.99485183869096, 76.39382339025335, 73.66608848732753, 74.21383647798741, 74.3568856113874, 73.99485183869096, 76.39382339025335, 73.66608848732753]

# %%
if True:
    print('Rebalance (sample down the majority class) and repeat')
    dataset_cyto,dataset_nuc = rebalance(dataset_cyto,dataset_nuc)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Rebalance (sample down the majority class) and repeat
# sample down to balance classes
# 1806 cytoplasmic samples
# 1806 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (3250, 1344)
# train set labels [0 1] counts [1632 1618]
# test set labels [0 1] counts [174 188]
# Round 1 Fold 1
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1286, number of negative: 1314
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.078873 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 334586
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.494615 -> initscore=-0.021539
# [LightGBM] [Info] Start training from score -0.021539
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1290, number of negative: 1310
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.094501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335134
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.496154 -> initscore=-0.015385
# [LightGBM] [Info] Start training from score -0.015385
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1286, number of negative: 1314
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.088356 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335010
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.494615 -> initscore=-0.021539
# [LightGBM] [Info] Start training from score -0.021539
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1309, number of negative: 1291
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.094479 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335096
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503462 -> initscore=0.013846
# [LightGBM] [Info] Start training from score 0.013846
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1301, number of negative: 1299
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.095487 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 334863
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500385 -> initscore=0.001538
# [LightGBM] [Info] Start training from score 0.001538
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1286, number of negative: 1314
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.101842 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 334586
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.494615 -> initscore=-0.021539
# [LightGBM] [Info] Start training from score -0.021539
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1290, number of negative: 1310
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.098142 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335134
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.496154 -> initscore=-0.015385
# [LightGBM] [Info] Start training from score -0.015385
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1286, number of negative: 1314
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.099868 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335010
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.494615 -> initscore=-0.021539
# [LightGBM] [Info] Start training from score -0.021539
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1309, number of negative: 1291
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.098799 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335096
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503462 -> initscore=0.013846
# [LightGBM] [Info] Start training from score 0.013846
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 2600 650
# Train
# [LightGBM] [Info] Number of positive: 1301, number of negative: 1299
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.102907 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 334863
# [LightGBM] [Info] Number of data points in the train set: 2600, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500385 -> initscore=0.001538
# [LightGBM] [Info] Start training from score 0.001538
# Validate
#
# Cross validation results
#   accuracy 68.52 mean,  1.108 stdev
# [70.46153846153847, 68.0, 67.23076923076923, 68.0, 68.92307692307692, 70.46153846153847, 68.0, 67.23076923076923, 68.0, 68.92307692307692]
#  precision 69.11 mean,  2.185 stdev
# [73.02631578947368, 68.40490797546013, 69.76744186046511, 66.88963210702342, 67.47720364741642, 73.02631578947368, 68.40490797546013, 69.76744186046511, 66.88963210702342, 67.47720364741642]
#     recall 66.57 mean,  2.387 stdev
# [66.86746987951807, 67.98780487804879, 63.25301204819277, 64.72491909385113, 70.03154574132492, 66.86746987951807, 67.98780487804879, 63.25301204819277, 64.72491909385113, 70.03154574132492]
#         F1 67.78 mean,  1.497 stdev
# [69.81132075471699, 68.19571865443426, 66.35071090047393, 65.78947368421053, 68.73065015479877, 69.81132075471699, 68.19571865443426, 66.35071090047393, 65.78947368421053, 68.73065015479877]
#        MCC 0.371 mean,  0.023 stdev
# [0.41157786126280793, 0.3599886387735912, 0.34723432133421495, 0.3576400972901759, 0.378907998612798, 0.41157786126280793, 0.3599886387735912, 0.34723432133421495, 0.3576400972901759, 0.378907998612798]
#      AUPRC 73.75 mean,  3.348 stdev
# [79.64330209051609, 74.7952926804097, 72.85611133232504, 69.98661933871976, 71.45863104707506, 79.64330209051609, 74.7952926804097, 72.85611133232504, 69.98661933871976, 71.45863104707506]
#      AUROC 74.44 mean,  1.954 stdev
# [77.0724407062211, 75.22629147098925, 71.64317647950293, 72.7927568829542, 75.44074042496756, 77.0724407062211, 75.22629147098925, 71.64317647950293, 72.7927568829542, 75.44074042496756]

# %%
if True:
    print('Use our lncATLAS training set "middle exclusion" (CN-RCI < -2 or CN-RCI > 0)')
    cyto_f = DATA_DIR+'ForRNAlight.lncRNA_RCIgt0.canonical.tsv'
    nuc_f  = DATA_DIR+'ForRNAlight.lncRNA_RCIlt-2.canonical.tsv'
    print('Data files:')
    print(cyto_f,'\n',nuc_f)
    dataset_cyto,dataset_nuc = load_dataframe(cyto_f,nuc_f)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Use our lncATLAS training set "middle exclusion" (CN-RCI < -2 or CN-RCI > 0)
# Data files:
# /content/drive/My Drive/data/Localization/RNAlight/ForRNAlight.lncRNA_RCIgt0.canonical.tsv
#  /content/drive/My Drive/data/Localization/RNAlight/ForRNAlight.lncRNA_RCIlt-2.canonical.tsv
# load dataframe
# 1703 cytoplasmic samples
# 706 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (2168, 1344)
# train set labels [0 1] counts [1524  644]
# test set labels [0 1] counts [179  62]
# Round 1 Fold 1
# Num samples in train and valid sets: 1734 434
# Train
# [LightGBM] [Info] Number of positive: 491, number of negative: 1243
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.048558 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326857
# [LightGBM] [Info] Number of data points in the train set: 1734, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.283160 -> initscore=-0.928839
# [LightGBM] [Info] Start training from score -0.928839
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 1734 434
# Train
# [LightGBM] [Info] Number of positive: 517, number of negative: 1217
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049318 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326619
# [LightGBM] [Info] Number of data points in the train set: 1734, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.298155 -> initscore=-0.856101
# [LightGBM] [Info] Start training from score -0.856101
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 1734 434
# Train
# [LightGBM] [Info] Number of positive: 525, number of negative: 1209
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.052156 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326180
# [LightGBM] [Info] Number of data points in the train set: 1734, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.302768 -> initscore=-0.834151
# [LightGBM] [Info] Start training from score -0.834151
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 1735 433
# Train
# [LightGBM] [Info] Number of positive: 522, number of negative: 1213
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054728 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326820
# [LightGBM] [Info] Number of data points in the train set: 1735, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.300865 -> initscore=-0.843184
# [LightGBM] [Info] Start training from score -0.843184
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 1735 433
# Train
# [LightGBM] [Info] Number of positive: 521, number of negative: 1214
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055210 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326641
# [LightGBM] [Info] Number of data points in the train set: 1735, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.300288 -> initscore=-0.845926
# [LightGBM] [Info] Start training from score -0.845926
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 1734 434
# Train
# [LightGBM] [Info] Number of positive: 491, number of negative: 1243
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.056164 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326857
# [LightGBM] [Info] Number of data points in the train set: 1734, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.283160 -> initscore=-0.928839
# [LightGBM] [Info] Start training from score -0.928839
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 1734 434
# Train
# [LightGBM] [Info] Number of positive: 517, number of negative: 1217
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057982 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326619
# [LightGBM] [Info] Number of data points in the train set: 1734, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.298155 -> initscore=-0.856101
# [LightGBM] [Info] Start training from score -0.856101
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 1734 434
# Train
# [LightGBM] [Info] Number of positive: 525, number of negative: 1209
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057177 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326180
# [LightGBM] [Info] Number of data points in the train set: 1734, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.302768 -> initscore=-0.834151
# [LightGBM] [Info] Start training from score -0.834151
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 1735 433
# Train
# [LightGBM] [Info] Number of positive: 522, number of negative: 1213
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057874 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326820
# [LightGBM] [Info] Number of data points in the train set: 1735, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.300865 -> initscore=-0.843184
# [LightGBM] [Info] Start training from score -0.843184
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 1735 433
# Train
# [LightGBM] [Info] Number of positive: 521, number of negative: 1214
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057250 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 326641
# [LightGBM] [Info] Number of data points in the train set: 1735, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.300288 -> initscore=-0.845926
# [LightGBM] [Info] Start training from score -0.845926
# Validate
#
# Cross validation results
#   accuracy 76.71 mean,  2.136 stdev
# [73.50230414746544, 75.11520737327189, 79.26267281105991, 78.52193995381063, 77.13625866050808, 73.50230414746544, 75.11520737327189, 79.26267281105991, 78.52193995381063, 77.13625866050808]
#  precision 70.17 mean,  3.851 stdev
# [76.38888888888889, 64.61538461538461, 71.64179104477611, 68.83116883116884, 69.35483870967742, 76.38888888888889, 64.61538461538461, 71.64179104477611, 68.83116883116884, 69.35483870967742]
#     recall 37.55 mean,  3.790 stdev
# [35.947712418300654, 33.07086614173229, 40.33613445378151, 43.44262295081967, 34.959349593495936, 35.947712418300654, 33.07086614173229, 40.33613445378151, 43.44262295081967, 34.959349593495936]
#         F1 48.80 mean,  3.427 stdev
# [48.88888888888888, 43.75000000000001, 51.61290322580645, 53.266331658291456, 46.48648648648649, 48.88888888888888, 43.75000000000001, 51.61290322580645, 53.266331658291456, 46.48648648648649]
#        MCC 0.385 mean,  0.036 stdev
# [0.38398909130693926, 0.3261256137469999, 0.4235532370710369, 0.4203093492969977, 0.3711932120749888, 0.38398909130693926, 0.3261256137469999, 0.4235532370710369, 0.4203093492969977, 0.3711932120749888]
#      AUPRC 64.62 mean,  3.720 stdev
# [69.65869565096136, 59.07587828233457, 63.37892322946708, 67.72869616374409, 63.254586708795756, 69.65869565096136, 59.07587828233457, 63.37892322946708, 67.72869616374409, 63.254586708795756]
#      AUROC 78.71 mean,  1.661 stdev
# [77.46144721233689, 76.66777809125651, 79.45845004668534, 81.44272837488799, 78.5156045108838, 77.46144721233689, 76.66777809125651, 79.45845004668534, 81.44272837488799, 78.5156045108838]

# %%
if True:   # just to be sure
    print('Rebalance (sample down the majority class) and repeat')
    dataset_cyto,dataset_nuc = rebalance(dataset_cyto,dataset_nuc)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Streaming output truncated to the last 5000 lines.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 1016 254
# Train
# [LightGBM] [Info] Number of positive: 500, number of negative: 516
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030511 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 281969
# [LightGBM] [Info] Number of data points in the train set: 1016, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.492126 -> initscore=-0.031499
# [LightGBM] [Info] Start training from score -0.031499
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Validate
#
# Cross validation results
#   accuracy 70.94 mean,  1.303 stdev
# [70.47244094488188, 72.83464566929135, 72.04724409448819, 70.07874015748031, 69.29133858267717, 70.47244094488188, 72.83464566929135, 72.04724409448819, 70.07874015748031, 69.29133858267717]
#  precision 72.22 mean,  0.853 stdev
# [72.22222222222221, 72.88135593220339, 73.39449541284404, 71.54471544715447, 71.05263157894737, 72.22222222222221, 72.88135593220339, 73.39449541284404, 71.54471544715447, 71.05263157894737]
#     recall 67.49 mean,  2.203 stdev
# [69.46564885496184, 69.91869918699187, 65.57377049180327, 68.21705426356588, 64.28571428571429, 69.46564885496184, 69.91869918699187, 65.57377049180327, 68.21705426356588, 64.28571428571429]
#         F1 69.76 mean,  1.347 stdev
# [70.8171206225681, 71.36929460580915, 69.26406926406926, 69.84126984126983, 67.5, 70.8171206225681, 71.36929460580915, 69.26406926406926, 69.84126984126983, 67.5]
#        MCC 0.419 mean,  0.025 stdev
# [0.409912888258054, 0.4558325282627102, 0.44014593383338263, 0.4023202710632721, 0.3870658884659865, 0.409912888258054, 0.4558325282627102, 0.44014593383338263, 0.4023202710632721, 0.3870658884659865]
#      AUPRC 79.32 mean,  1.025 stdev
# [79.222383907244, 77.4872105954081, 79.91038158111111, 80.55719664752212, 79.39978213082044, 79.222383907244, 77.4872105954081, 79.91038158111111, 80.55719664752212, 79.39978213082044]
#      AUROC 79.14 mean,  1.380 stdev
# [77.65158567616211, 79.96648668776764, 80.27819175360159, 80.52713178294574, 77.29414682539681, 77.65158567616211, 79.96648668776764, 80.27819175360159, 80.52713178294574, 77.29414682539681]

# %%
if True:
    print('Use our lncATLAS training set "all" (-inf <= CN-RCI <= +inf)')
    cyto_f = DATA_DIR+'ForRNAlight.lncRNA_RCIgt-1.canonical.tsv'
    nuc_f  = DATA_DIR+'ForRNAlight.lncRNA_RCIlt-1.canonical.tsv'
    print(cyto_f,'\n',nuc_f)
    dataset_cyto,dataset_nuc = load_dataframe(cyto_f,nuc_f)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Use our lncATLAS training set "all" (-inf <= CN-RCI <= +inf)
# /content/drive/My Drive/data/Localization/RNAlight/ForRNAlight.lncRNA_RCIgt-1.canonical.tsv
#  /content/drive/My Drive/data/Localization/RNAlight/ForRNAlight.lncRNA_RCIlt-1.canonical.tsv
# load dataframe
# 2887 cytoplasmic samples
# 1548 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (3991, 1344)
# train set labels [0 1] counts [2606 1385]
# test set labels [0 1] counts [281 163]
# Round 1 Fold 1
# Num samples in train and valid sets: 3192 799
# Train
# [LightGBM] [Info] Number of positive: 1102, number of negative: 2090
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.100901 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 340977
# [LightGBM] [Info] Number of data points in the train set: 3192, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.345238 -> initscore=-0.640037
# [LightGBM] [Info] Start training from score -0.640037
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 3193 798
# Train
# [LightGBM] [Info] Number of positive: 1098, number of negative: 2095
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.123088 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 341051
# [LightGBM] [Info] Number of data points in the train set: 3193, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.343877 -> initscore=-0.646063
# [LightGBM] [Info] Start training from score -0.646063
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 3193 798
# Train
# [LightGBM] [Info] Number of positive: 1099, number of negative: 2094
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.119142 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 341021
# [LightGBM] [Info] Number of data points in the train set: 3193, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.344190 -> initscore=-0.644675
# [LightGBM] [Info] Start training from score -0.644675
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 3193 798
# Train
# [LightGBM] [Info] Number of positive: 1134, number of negative: 2059
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.132587 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 341022
# [LightGBM] [Info] Number of data points in the train set: 3193, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.355152 -> initscore=-0.596469
# [LightGBM] [Info] Start training from score -0.596469
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 3193 798
# Train
# [LightGBM] [Info] Number of positive: 1107, number of negative: 2086
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.127175 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 340953
# [LightGBM] [Info] Number of data points in the train set: 3193, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.346696 -> initscore=-0.633595
# [LightGBM] [Info] Start training from score -0.633595
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 3192 799
# Train
# [LightGBM] [Info] Number of positive: 1102, number of negative: 2090
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.134370 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 340977
# [LightGBM] [Info] Number of data points in the train set: 3192, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.345238 -> initscore=-0.640037
# [LightGBM] [Info] Start training from score -0.640037
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 3193 798
# Train
# [LightGBM] [Info] Number of positive: 1098, number of negative: 2095
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.125579 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 341051
# [LightGBM] [Info] Number of data points in the train set: 3193, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.343877 -> initscore=-0.646063
# [LightGBM] [Info] Start training from score -0.646063
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 3193 798
# Train
# [LightGBM] [Info] Number of positive: 1099, number of negative: 2094
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.138122 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 341021
# [LightGBM] [Info] Number of data points in the train set: 3193, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.344190 -> initscore=-0.644675
# [LightGBM] [Info] Start training from score -0.644675
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 3193 798
# Train
# [LightGBM] [Info] Number of positive: 1134, number of negative: 2059
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.125450 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 341022
# [LightGBM] [Info] Number of data points in the train set: 3193, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.355152 -> initscore=-0.596469
# [LightGBM] [Info] Start training from score -0.596469
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 3193 798
# Train
# [LightGBM] [Info] Number of positive: 1107, number of negative: 2086
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.128107 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 340953
# [LightGBM] [Info] Number of data points in the train set: 3193, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.346696 -> initscore=-0.633595
# [LightGBM] [Info] Start training from score -0.633595
# Validate
#
# Cross validation results
#   accuracy 69.18 mean,  1.969 stdev
# [71.08886107634544, 67.66917293233082, 66.9172932330827, 71.9298245614035, 68.29573934837093, 71.08886107634544, 67.66917293233082, 66.9172932330827, 71.9298245614035, 68.29573934837093]
#  precision 61.15 mean,  2.885 stdev
# [65.85365853658537, 62.83185840707964, 58.333333333333336, 60.46511627906976, 58.27814569536424, 65.85365853658537, 62.83185840707964, 58.333333333333336, 60.46511627906976, 58.27814569536424]
#     recall 30.51 mean,  4.612 stdev
# [38.16254416961131, 24.738675958188153, 26.923076923076923, 31.07569721115538, 31.654676258992804, 38.16254416961131, 24.738675958188153, 26.923076923076923, 31.07569721115538, 31.654676258992804]
#         F1 40.55 mean,  4.475 stdev
# [48.322147651006716, 35.50000000000001, 36.84210526315789, 41.05263157894737, 41.02564102564102, 48.322147651006716, 35.50000000000001, 36.84210526315789, 41.05263157894737, 41.02564102564102]
#        MCC 0.254 mean,  0.041 stdev
# [0.3233912718732613, 0.2273860059816059, 0.20883164373978785, 0.274362076500308, 0.23767979872453887, 0.3233912718732613, 0.2273860059816059, 0.20883164373978785, 0.274362076500308, 0.23767979872453887]
#      AUPRC 56.51 mean,  2.778 stdev
# [59.81093787945849, 59.01439028274596, 56.485473296921555, 55.14468896176693, 52.08856254992317, 59.81093787945849, 59.01439028274596, 56.485473296921555, 55.14468896176693, 52.08856254992317]
#      AUROC 69.63 mean,  1.022 stdev
# [70.41046922508012, 69.7443695152635, 70.08645651223776, 70.26810491125079, 67.63420033204206, 70.41046922508012, 69.7443695152635, 70.08645651223776, 70.26810491125079, 67.63420033204206]

# %%
if True:
    print('Rebalance (sample down the majority class) and repeat')
    dataset_cyto,dataset_nuc = rebalance(dataset_cyto,dataset_nuc)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Rebalance (sample down the majority class) and repeat
# sample down to balance classes
# 1548 cytoplasmic samples
# 1548 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (2786, 1344)
# train set labels [0 1] counts [1397 1389]
# test set labels [0 1] counts [151 159]
# Round 1 Fold 1
# Num samples in train and valid sets: 2228 558
# Train
# [LightGBM] [Info] Number of positive: 1096, number of negative: 1132
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.072786 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335379
# [LightGBM] [Info] Number of data points in the train set: 2228, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.491921 -> initscore=-0.032319
# [LightGBM] [Info] Start training from score -0.032319
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 2229 557
# Train
# [LightGBM] [Info] Number of positive: 1086, number of negative: 1143
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.082911 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335465
# [LightGBM] [Info] Number of data points in the train set: 2229, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.487214 -> initscore=-0.051155
# [LightGBM] [Info] Start training from score -0.051155
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 2229 557
# Train
# [LightGBM] [Info] Number of positive: 1120, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.082198 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335620
# [LightGBM] [Info] Number of data points in the train set: 2229, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.502467 -> initscore=0.009870
# [LightGBM] [Info] Start training from score 0.009870
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 2229 557
# Train
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1098
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.079340 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335509
# [LightGBM] [Info] Number of data points in the train set: 2229, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.507402 -> initscore=0.029612
# [LightGBM] [Info] Start training from score 0.029612
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 2229 557
# Train
# [LightGBM] [Info] Number of positive: 1123, number of negative: 1106
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.088820 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335644
# [LightGBM] [Info] Number of data points in the train set: 2229, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503813 -> initscore=0.015254
# [LightGBM] [Info] Start training from score 0.015254
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 2228 558
# Train
# [LightGBM] [Info] Number of positive: 1096, number of negative: 1132
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.083642 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335379
# [LightGBM] [Info] Number of data points in the train set: 2228, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.491921 -> initscore=-0.032319
# [LightGBM] [Info] Start training from score -0.032319
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 2229 557
# Train
# [LightGBM] [Info] Number of positive: 1086, number of negative: 1143
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.079490 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335465
# [LightGBM] [Info] Number of data points in the train set: 2229, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.487214 -> initscore=-0.051155
# [LightGBM] [Info] Start training from score -0.051155
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 2229 557
# Train
# [LightGBM] [Info] Number of positive: 1120, number of negative: 1109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.081155 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335620
# [LightGBM] [Info] Number of data points in the train set: 2229, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.502467 -> initscore=0.009870
# [LightGBM] [Info] Start training from score 0.009870
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 2229 557
# Train
# [LightGBM] [Info] Number of positive: 1131, number of negative: 1098
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.081517 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335509
# [LightGBM] [Info] Number of data points in the train set: 2229, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.507402 -> initscore=0.029612
# [LightGBM] [Info] Start training from score 0.029612
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 2229 557
# Train
# [LightGBM] [Info] Number of positive: 1123, number of negative: 1106
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.079132 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 335644
# [LightGBM] [Info] Number of data points in the train set: 2229, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503813 -> initscore=0.015254
# [LightGBM] [Info] Start training from score 0.015254
# Validate
#
# Cross validation results
#   accuracy 63.39 mean,  1.656 stdev
# [63.261648745519715, 61.57989228007181, 63.37522441651705, 66.42728904847397, 62.29802513464991, 63.261648745519715, 61.57989228007181, 63.37522441651705, 66.42728904847397, 62.29802513464991]
#  precision 64.19 mean,  2.798 stdev
# [66.2962962962963, 68.16326530612244, 62.45210727969349, 63.81322957198443, 60.21897810218978, 66.2962962962963, 68.16326530612244, 62.45210727969349, 63.81322957198443, 60.21897810218978]
#     recall 60.48 mean,  2.867 stdev
# [61.092150170648466, 55.115511551155116, 60.594795539033456, 63.565891472868216, 62.03007518796993, 61.092150170648466, 55.115511551155116, 60.594795539033456, 63.565891472868216, 62.03007518796993]
#         F1 62.17 mean,  1.214 stdev
# [63.58792184724689, 60.94890510948904, 61.50943396226415, 63.689320388349515, 61.11111111111111, 63.58792184724689, 60.94890510948904, 61.50943396226415, 63.689320388349515, 61.11111111111111]
#        MCC 0.270 mean,  0.029 stdev
# [0.2673273792658616, 0.24490044136181785, 0.2660413119182215, 0.32471053187061893, 0.24551471883106407, 0.2673273792658616, 0.24490044136181785, 0.2660413119182215, 0.32471053187061893, 0.24551471883106407]
#      AUPRC 68.81 mean,  2.833 stdev
# [71.2318905133718, 71.7567807949175, 67.84558503465357, 69.33582986532322, 63.87361180336772, 71.2318905133718, 71.7567807949175, 67.84558503465357, 69.33582986532322, 63.87361180336772]
#      AUROC 68.78 mean,  1.734 stdev
# [69.03342134071737, 67.38910111483588, 68.09298843453118, 72.01913354592828, 67.34232488437588, 69.03342134071737, 67.38910111483588, 68.09298843453118, 72.01913354592828, 67.34232488437588]

# %%
print(datetime.now())
print('Done')
# Out:
# 2024-06-04 19:00:25.074157
# Done
