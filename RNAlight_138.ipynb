# %% [markdown]
# # LightGBM with default hyperparameters
# mRNA.
# CoLab L4 himem.
# Model = LG2 (optimized parameters)
# In RNAlight, 1=nuclear.

# %%
import time
from datetime import datetime
print(datetime.now())
# Out:
# 2024-06-04 19:39:50.042780

# %%
import os
import copy
import random
import collections
import itertools
import numpy as np
import pandas as pd
#import lightgbm as lgb
import warnings
from sklearn import svm
#from sklearn.externals import joblib
import joblib
#from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split,RandomizedSearchCV
#import sklearn.metrics as metrics
# from sklearn.linear_model import LogisticRegression
import lightgbm
print('Done')
# Out:
# Done

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
print('Done')
# Out:
# Done

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    print('Running on CoLab')
    PATH='/content/drive/'
    drive.mount(PATH)
    DATA_DIR=PATH+'My Drive/data/Localization/RNAlight/'  # must end in "/"
    MODEL_DIR=PATH+'My Drive/data/Localization/RNAlight/'  # must end in "/"
    output_dir=PATH+'My Drive/data/Localization/RNAlight/'
except:
    IN_COLAB = False
    DATA_DIR = './'    # Mac
    MODEL_DIR = './'    # Mac
    output_dir = './'
print('DATA DIR', DATA_DIR)
# Out:
# Running on CoLab
# Mounted at /content/drive/
# DATA DIR /content/drive/My Drive/data/Localization/RNAlight/

# %%
SEED = 100
random.seed(SEED)
np.random.seed(SEED)
print(SEED)
# Out:
# 100

# %%
def build_model():
    new_model = lightgbm.LGBMClassifier(
        boosting_type='gbdt',
        class_weight=None,
        colsample_bytree=0.5,
        importance_type='split',
        learning_rate=0.01,
        max_depth=40,
        min_child_samples=9,
        min_child_weight=0.001,
        min_split_gain=0.0,
        n_estimators=2200,
        n_jobs=1,
        num_leaves=35,
        objective='binary',
        random_state=100,
        reg_alpha=0.005,
        reg_lambda=0,
        subsample=0.6,
        subsample_for_bin=200000,
        subsample_freq=1,
        metric='binary_logloss'
    )
    return new_model

# %%
test = build_model()
print(test)
test = None
# Out:
# LGBMClassifier(colsample_bytree=0.5, learning_rate=0.01, max_depth=40,
#                metric='binary_logloss', min_child_samples=9, n_estimators=2200,
#                n_jobs=1, num_leaves=35, objective='binary', random_state=100,
#                reg_alpha=0.005, reg_lambda=0, subsample=0.6, subsample_freq=1)

# %%
class stats_collector:
    def __init__(self):
        self.reset_statistics()
    def reset_statistics(self):
        self.cv_accuracy=[]
        self.cv_precision=[]
        self.cv_recall=[]
        self.cv_f1=[]
        self.cv_mcc=[]
        self.cv_auprc=[]
        self.cv_auroc=[]
    def _append_statistics(self,accuracy,precision,recall,f1,mcc,auprc,auroc):
        self.cv_accuracy.append(accuracy)
        self.cv_precision.append(precision)
        self.cv_recall.append(recall)
        self.cv_f1.append(f1)
        self.cv_mcc.append(mcc)
        self.cv_auprc.append(auprc)
        self.cv_auroc.append(auroc)
    def compute_performance(self,y_test,yhat_pred,yhat_classes,verbose=False):
        accuracy = accuracy_score(y_test, yhat_classes)*100.
        precision = precision_score(y_test, yhat_classes)*100.
        recall = recall_score(y_test, yhat_classes)*100.
        f1 = f1_score(y_test, yhat_classes)*100.
        mcc = matthews_corrcoef(y_test, yhat_classes)
        prc_Y, prc_X, prc_bins = precision_recall_curve(y_test, yhat_pred)
        auprc = auc(prc_X,prc_Y)*100.
        auroc = roc_auc_score(y_test, yhat_pred)*100.
        self._append_statistics(accuracy,precision,recall,f1,mcc,auprc,auroc)
        if verbose:
            self._show_confusion(y_test,yhat_pred,yhat_classes)
            self._show_statistics(accuracy,precision,recall,f1,mcc,auprc,auroc)
    def _show_confusion(self,y_test,yhat_pred,yhat_classes):
            print('Distrib of scores:',np.mean(yhat_pred),'mean',np.std(yhat_pred),'std')
            print('Range of scores:',np.min(yhat_pred),'to',np.max(yhat_pred))
            cm1 = confusion_matrix(y_test,yhat_classes)
            print('Confusion matrix\n',cm1)
            cm2 = confusion_matrix(y_test,yhat_classes,normalize='all')
            print('Normalized matrix\n',cm2)
    def _show_statistics(self,accuracy,precision,recall,f1,mcc,auprc,auroc):
            print('accuracy:',accuracy,'precision:',precision,'recall:',recall,\
                  'F1:',f1,'MCC:',mcc,'AUPRC:',auprc,'AUROC:',auroc)
    def _show_variance(self, name, stats_list):
        if name=='MCC':
            print('%10s %5.3f mean, %6.3f stdev' % (name,np.mean(stats_list),np.std(stats_list) ) )
        else:
            print('%10s %5.2f mean, %6.3f stdev' % (name,np.mean(stats_list),np.std(stats_list) ) )
        print(stats_list)
    def dump_all(self):
        self._show_variance('accuracy', self.cv_accuracy)
        self._show_variance('precision',self.cv_precision)
        self._show_variance('recall',   self.cv_recall)
        self._show_variance('F1',       self.cv_f1)
        self._show_variance('MCC',      self.cv_mcc)
        self._show_variance('AUPRC',    self.cv_auprc)
        self._show_variance('AUROC',    self.cv_auroc)

# %%
# From RNAlight notebook
def _count_kmer(Dataset,k): # k = 3,4,5

    # copy dataset
    dataset = copy.deepcopy(Dataset)
    # alphbet of nucleotide
    nucleotide = ['A','C','G','T']

    # generate k-mers
    #  k == 5:
    five = list(itertools.product(nucleotide,repeat=5))
    pentamer = []
    for n in five:
        pentamer.append("".join(n))

    #  k == 4:
    four = list(itertools.product(nucleotide,repeat=4))
    tetramer = []
    for n in four:
        tetramer.append("".join(n))

    # k == 3:
    three = list(itertools.product(nucleotide,repeat=3))
    threemer = []
    for n in three:
        threemer.append("".join(n))

    # input features can be combinations of diffrent k values
    if k == 34:
        table_kmer = dict.fromkeys(threemer,0)
        table_kmer.update(dict.fromkeys(tetramer,0))
    if k == 45:
        table_kmer = dict.fromkeys(tetramer,0)
        table_kmer.update(dict.fromkeys(pentamer,0))
    if k == 345:
        table_kmer = dict.fromkeys(threemer,0)
        table_kmer.update(dict.fromkeys(tetramer,0))
        table_kmer.update(dict.fromkeys(pentamer,0))

    # count k-mer for each sequence
    for mer in table_kmer.keys():
        table_kmer[mer] = dataset["cdna"].apply(lambda x : x.count(mer))

    # for k-mer raw count without normalization, index: nuc:1 or cyto:0
    rawcount_kmer_df = pd.DataFrame(table_kmer)
    df1_rawcount = pd.concat([rawcount_kmer_df,dataset["ensembl_transcript_id"]],axis = 1)
    df1_rawcount.index = dataset["tag"]

    # for k-mer frequency with normalization , index: nuc:1 or cyto:0
    freq_kmer_df = rawcount_kmer_df.apply(lambda x: x/x.sum(),axis=1)
    df1 = pd.concat([freq_kmer_df,dataset["ensembl_transcript_id"]],axis = 1)
    df1.index = dataset["tag"]

    return df1  # ,df1_rawcount

# %%
# From RNAlight notebook
def load_dataframe(cyto_f,nuc_f):
    print('load dataframe')
    dataset_cyto = pd.read_csv(cyto_f,sep='\t',index_col = False)    #1806
    dataset_nuc = pd.read_csv(nuc_f,sep='\t',index_col = False)    #1986
    print( len(dataset_cyto), 'cytoplasmic samples')
    print( len(dataset_nuc),  'nuclear samples')
    return dataset_cyto,dataset_nuc

# %%
# Added
def rebalance(dataset_cyto,dataset_nuc):
    print('sample down to balance classes')
    min_size = min(len(dataset_cyto),len(dataset_nuc))
    # random sampling without replacement
    dataset_cyto = dataset_cyto.sample(min_size, random_state=SEED)
    dataset_nuc  = dataset_nuc.sample(min_size,  random_state=SEED)
    print( len(dataset_cyto), 'cytoplasmic samples')
    print( len(dataset_nuc),  'nuclear samples')
    return dataset_cyto,dataset_nuc

# %%
# From RNAlight notebook
def extract_features_and_split(dataset_cyto,dataset_nuc):
    print('add labels, concatenate')
    # Set the tag of RCI(log2FC): nuclear 1 / cytosol 0
    dataset_nuc['tag'] = 1;dataset_cyto['tag'] = 0
    # merge the nuc and cyto dataset
    dataset = pd.concat([dataset_nuc,dataset_cyto]) # 3792

    print('dedupe (probably not necessary)')
    # remove duplications(actually,each mRNA is unique in its class)
    dataset.drop_duplicates(keep="first",subset=["ensembl_transcript_id","name","cdna"],inplace=True) # 3792

    print('count kmers')
    # k = 3,4,5 count the normalized and raw count of kmer
    df_kmer_345 = _count_kmer(dataset,345)   # df_kmer_345,df_kmer_345_rawcount =

    # We commented this out. No need to save the tsv.
    # df_kmer_345.to_csv(os.path.join(output_dir,"df_kmer345_freq.tsv"),sep='\t')
    # This was commented out in the original. Seems they reran using saved kmers. Should test if file exists.
    # load kmer file
    # df_kmer_345 = pd.read_csv(os.path.join(output_dir,"df_kmer345_freq.tsv"),sep='\t',index_col= 0)

    # convert to x:kmer-freq , y:label
    del df_kmer_345['ensembl_transcript_id']
    x_kmer = df_kmer_345.values
    y_kmer = y_kmer = np.array(df_kmer_345.index)

    # split into training and test sets (9:1)
    print('train/test split')
    x_train, x_test, y_train, y_test = train_test_split(x_kmer, y_kmer, test_size = 0.1, random_state = SEED)

    #print('Apply cross-validation to all the data (no test set withheld)')
    #x_train, x_test, y_train, y_test = train_test_split(x_kmer, y_kmer, test_size = None, random_state = SEED)
    print('train set shape',x_train.shape)
    # Added
    labels,counts = np.unique(y_train,return_counts=True)
    print('train set labels', labels, 'counts',counts)
    labels,counts = np.unique(y_test,return_counts=True)
    print('test set labels', labels, 'counts',counts)
    return x_train, x_test, y_train, y_test

# %%
def do_cv(x_train, y_train):
    stats = stats_collector()
    for round in range(1,3):
        fold=0
        splitter = KFold(n_splits=5)
        for train_index, valid_index in splitter.split(x_train):
            fold += 1
            print('Round', round, 'Fold', fold)
            print('Num samples in train and valid sets:', len(train_index), len(valid_index))
            print('Train')
            lgb = build_model()
            history = lgb.fit(x_train[train_index], y_train[train_index])
            print('Validate')
            x_valid = x_train[valid_index]
            y_valid = y_train[valid_index]
            yhat_classes= lgb.predict(x_valid)  # get 0 or 1
            yhat_pairs=   lgb.predict_proba(x_valid)  # get [ prob of 0, prob of 1 ]
            yhat_pred=    [pair[1] for pair in yhat_pairs]
            stats.compute_performance(y_valid,yhat_pred,yhat_classes,verbose=False)
    return stats

# %%
if True:
    print('Use the RNAlight training set (already has middle excluded)')
    cyto_f = DATA_DIR+'02_mRNA_info_cyto_transcript.tsv'
    nuc_f  = DATA_DIR+'02_mRNA_info_nuc_transcript.tsv'
    print('Data files:')
    print(cyto_f,'\n',nuc_f)
    dataset_cyto,dataset_nuc = load_dataframe(cyto_f,nuc_f)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Use the RNAlight training set (already has middle excluded)
# Data files:
# /content/drive/My Drive/data/Localization/RNAlight/02_mRNA_info_cyto_transcript.tsv
#  /content/drive/My Drive/data/Localization/RNAlight/02_mRNA_info_nuc_transcript.tsv
# load dataframe
# 2924 cytoplasmic samples
# 2256 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (4662, 1344)
# train set labels [0 1] counts [2642 2020]
# test set labels [0 1] counts [282 236]
# Round 1 Fold 1
# Num samples in train and valid sets: 3729 933
# Train
# [LightGBM] [Info] Number of positive: 1621, number of negative: 2108
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.076859 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3729, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.434701 -> initscore=-0.262696
# [LightGBM] [Info] Start training from score -0.262696
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 3729 933
# Train
# [LightGBM] [Info] Number of positive: 1606, number of negative: 2123
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021534 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3729, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.430678 -> initscore=-0.279084
# [LightGBM] [Info] Start training from score -0.279084
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 3730 932
# Train
# [LightGBM] [Info] Number of positive: 1631, number of negative: 2099
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.101638 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.437265 -> initscore=-0.252268
# [LightGBM] [Info] Start training from score -0.252268
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 3730 932
# Train
# [LightGBM] [Info] Number of positive: 1604, number of negative: 2126
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.108356 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.430027 -> initscore=-0.281742
# [LightGBM] [Info] Start training from score -0.281742
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 3730 932
# Train
# [LightGBM] [Info] Number of positive: 1618, number of negative: 2112
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.112254 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.433780 -> initscore=-0.266445
# [LightGBM] [Info] Start training from score -0.266445
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 3729 933
# Train
# [LightGBM] [Info] Number of positive: 1621, number of negative: 2108
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.110824 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3729, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.434701 -> initscore=-0.262696
# [LightGBM] [Info] Start training from score -0.262696
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 3729 933
# Train
# [LightGBM] [Info] Number of positive: 1606, number of negative: 2123
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.117700 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3729, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.430678 -> initscore=-0.279084
# [LightGBM] [Info] Start training from score -0.279084
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 3730 932
# Train
# [LightGBM] [Info] Number of positive: 1631, number of negative: 2099
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.112624 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.437265 -> initscore=-0.252268
# [LightGBM] [Info] Start training from score -0.252268
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 3730 932
# Train
# [LightGBM] [Info] Number of positive: 1604, number of negative: 2126
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.112464 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.430027 -> initscore=-0.281742
# [LightGBM] [Info] Start training from score -0.281742
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 3730 932
# Train
# [LightGBM] [Info] Number of positive: 1618, number of negative: 2112
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.115093 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3730, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.433780 -> initscore=-0.266445
# [LightGBM] [Info] Start training from score -0.266445
# Validate
#
# Cross validation results
#   accuracy 70.03 mean,  1.144 stdev
# [70.09646302250803, 67.84565916398714, 70.60085836909872, 71.13733905579399, 70.49356223175965, 70.09646302250803, 67.84565916398714, 70.60085836909872, 71.13733905579399, 70.49356223175965]
#  precision 69.30 mean,  2.353 stdev
# [69.35483870967742, 67.5925925925926, 66.86217008797654, 73.63344051446946, 69.06906906906907, 69.35483870967742, 67.5925925925926, 66.86217008797654, 73.63344051446946, 69.06906906906907]
#     recall 55.53 mean,  2.107 stdev
# [53.88471177944862, 52.89855072463768, 58.61182519280206, 55.04807692307693, 57.2139303482587, 53.88471177944862, 52.89855072463768, 58.61182519280206, 55.04807692307693, 57.2139303482587]
#         F1 61.61 mean,  1.389 stdev
# [60.648801128349795, 59.34959349593496, 62.465753424657535, 62.998624484181576, 62.58503401360544, 60.648801128349795, 59.34959349593496, 62.465753424657535, 62.998624484181576, 62.58503401360544]
#        MCC 0.382 mean,  0.023 stdev
# [0.3791164507521795, 0.34089170131945934, 0.3870017760725196, 0.4128103155057633, 0.39046042269828357, 0.3791164507521795, 0.34089170131945934, 0.3870017760725196, 0.4128103155057633, 0.39046042269828357]
#      AUPRC 71.58 mean,  1.779 stdev
# [71.77077826765301, 70.48905750993984, 69.58299928025029, 74.81871830679476, 71.23577211256212, 71.77077826765301, 70.48905750993984, 69.58299928025029, 74.81871830679476, 71.23577211256212]
#      AUROC 75.80 mean,  1.680 stdev
# [76.9456412566998, 73.61378719760222, 74.83181600837014, 78.40125596302921, 75.23092086736132, 76.9456412566998, 73.61378719760222, 74.83181600837014, 78.40125596302921, 75.23092086736132]

# %%
if True:
    print('Rebalance (sample down the majority class) and repeat')
    dataset_cyto,dataset_nuc = rebalance(dataset_cyto,dataset_nuc)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Rebalance (sample down the majority class) and repeat
# sample down to balance classes
# 2256 cytoplasmic samples
# 2256 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (4060, 1344)
# train set labels [0 1] counts [2029 2031]
# test set labels [0 1] counts [227 225]
# Round 1 Fold 1
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1632, number of negative: 1616
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.063388 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.502463 -> initscore=0.009852
# [LightGBM] [Info] Start training from score 0.009852
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1608, number of negative: 1640
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.079847 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495074 -> initscore=-0.019705
# [LightGBM] [Info] Start training from score -0.019705
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1632, number of negative: 1616
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.083652 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.502463 -> initscore=0.009852
# [LightGBM] [Info] Start training from score 0.009852
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1626, number of negative: 1622
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087033 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500616 -> initscore=0.002463
# [LightGBM] [Info] Start training from score 0.002463
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1626, number of negative: 1622
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090940 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500616 -> initscore=0.002463
# [LightGBM] [Info] Start training from score 0.002463
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1632, number of negative: 1616
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.084011 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.502463 -> initscore=0.009852
# [LightGBM] [Info] Start training from score 0.009852
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1608, number of negative: 1640
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086915 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495074 -> initscore=-0.019705
# [LightGBM] [Info] Start training from score -0.019705
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1632, number of negative: 1616
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.085191 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.502463 -> initscore=0.009852
# [LightGBM] [Info] Start training from score 0.009852
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1626, number of negative: 1622
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.090034 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500616 -> initscore=0.002463
# [LightGBM] [Info] Start training from score 0.002463
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 3248 812
# Train
# [LightGBM] [Info] Number of positive: 1626, number of negative: 1622
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.087030 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 3248, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500616 -> initscore=0.002463
# [LightGBM] [Info] Start training from score 0.002463
# Validate
#
# Cross validation results
#   accuracy 68.72 mean,  1.665 stdev
# [69.95073891625616, 66.87192118226602, 70.93596059113301, 66.7487684729064, 69.08866995073892, 69.95073891625616, 66.87192118226602, 70.93596059113301, 66.7487684729064, 69.08866995073892]
#  precision 69.27 mean,  1.525 stdev
# [69.42355889724311, 70.6989247311828, 69.73365617433413, 66.34382566585957, 70.15706806282722, 69.42355889724311, 70.6989247311828, 69.73365617433413, 66.34382566585957, 70.15706806282722]
#     recall 67.52 mean,  3.339 stdev
# [69.42355889724311, 62.174940898345156, 72.18045112781954, 67.65432098765433, 66.17283950617285, 69.42355889724311, 62.174940898345156, 72.18045112781954, 67.65432098765433, 66.17283950617285]
#         F1 68.32 mean,  1.704 stdev
# [69.42355889724311, 66.16352201257862, 70.935960591133, 66.99266503667482, 68.10673443456163, 69.42355889724311, 66.16352201257862, 70.935960591133, 66.99266503667482, 68.10673443456163]
#        MCC 0.376 mean,  0.032 stdev
# [0.3988360732339323, 0.342447123875522, 0.4191410730215369, 0.3350686579507302, 0.38229748868127167, 0.3988360732339323, 0.342447123875522, 0.4191410730215369, 0.3350686579507302, 0.38229748868127167]
#      AUPRC 75.74 mean,  1.510 stdev
# [76.39083516160542, 74.55814002745875, 78.23282455723472, 73.9123462418091, 75.60210941440151, 76.39083516160542, 74.55814002745875, 78.23282455723472, 73.9123462418091, 75.60210941440151]
#      AUROC 76.02 mean,  1.590 stdev
# [77.15535812897862, 74.6832212073146, 78.4594658559231, 74.1529408196075, 75.65868899202232, 77.15535812897862, 74.6832212073146, 78.4594658559231, 74.1529408196075, 75.65868899202232]

# %%
if True:
    print('Use our lncATLAS training set "middle exclusion" (CN-RCI < -2 or CN-RCI > 0)')
    cyto_f = DATA_DIR+'ForRNAlight.mRNA_RCIgt0.canonical.tsv'
    nuc_f  = DATA_DIR+'ForRNAlight.mRNA_RCIlt-2.canonical.tsv'
    print('Data files:')
    print(cyto_f,'\n',nuc_f)
    dataset_cyto,dataset_nuc = load_dataframe(cyto_f,nuc_f)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Use our lncATLAS training set "middle exclusion" (CN-RCI < -2 or CN-RCI > 0)
# Data files:
# /content/drive/My Drive/data/Localization/RNAlight/ForRNAlight.mRNA_RCIgt0.canonical.tsv
#  /content/drive/My Drive/data/Localization/RNAlight/ForRNAlight.mRNA_RCIlt-2.canonical.tsv
# load dataframe
# 7909 cytoplasmic samples
# 987 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (8006, 1344)
# train set labels [0 1] counts [7136  870]
# test set labels [0 1] counts [773 117]
# Round 1 Fold 1
# Num samples in train and valid sets: 6404 1602
# Train
# [LightGBM] [Info] Number of positive: 685, number of negative: 5719
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.179362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6404, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.106964 -> initscore=-2.122130
# [LightGBM] [Info] Start training from score -2.122130
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 6405 1601
# Train
# [LightGBM] [Info] Number of positive: 692, number of negative: 5713
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.170818 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6405, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.108041 -> initscore=-2.110914
# [LightGBM] [Info] Start training from score -2.110914
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 6405 1601
# Train
# [LightGBM] [Info] Number of positive: 695, number of negative: 5710
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.190349 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6405, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.108509 -> initscore=-2.106062
# [LightGBM] [Info] Start training from score -2.106062
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 6405 1601
# Train
# [LightGBM] [Info] Number of positive: 698, number of negative: 5707
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.188283 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6405, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.108977 -> initscore=-2.101230
# [LightGBM] [Info] Start training from score -2.101230
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 6405 1601
# Train
# [LightGBM] [Info] Number of positive: 710, number of negative: 5695
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.182810 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6405, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110851 -> initscore=-2.082079
# [LightGBM] [Info] Start training from score -2.082079
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 6404 1602
# Train
# [LightGBM] [Info] Number of positive: 685, number of negative: 5719
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.181206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6404, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.106964 -> initscore=-2.122130
# [LightGBM] [Info] Start training from score -2.122130
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 6405 1601
# Train
# [LightGBM] [Info] Number of positive: 692, number of negative: 5713
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.184256 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6405, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.108041 -> initscore=-2.110914
# [LightGBM] [Info] Start training from score -2.110914
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 6405 1601
# Train
# [LightGBM] [Info] Number of positive: 695, number of negative: 5710
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.178791 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6405, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.108509 -> initscore=-2.106062
# [LightGBM] [Info] Start training from score -2.106062
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 6405 1601
# Train
# [LightGBM] [Info] Number of positive: 698, number of negative: 5707
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.183396 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6405, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.108977 -> initscore=-2.101230
# [LightGBM] [Info] Start training from score -2.101230
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 6405 1601
# Train
# [LightGBM] [Info] Number of positive: 710, number of negative: 5695
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.178538 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 6405, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.110851 -> initscore=-2.082079
# [LightGBM] [Info] Start training from score -2.082079
# Validate
#
# Cross validation results
#   accuracy 93.03 mean,  0.469 stdev
# [93.63295880149812, 92.81698938163647, 92.3797626483448, 93.50405996252343, 92.81698938163647, 93.63295880149812, 92.81698938163647, 92.3797626483448, 93.50405996252343, 92.81698938163647]
#  precision 83.21 mean,  4.377 stdev
# [91.0891089108911, 82.4742268041237, 78.49462365591397, 84.0, 80.0, 91.0891089108911, 82.4742268041237, 78.49462365591397, 84.0, 80.0]
#     recall 44.55 mean,  4.541 stdev
# [49.72972972972973, 44.9438202247191, 41.714285714285715, 48.837209302325576, 37.5, 49.72972972972973, 44.9438202247191, 41.714285714285715, 48.837209302325576, 37.5]
#         F1 57.96 mean,  4.793 stdev
# [64.33566433566433, 58.18181818181818, 54.47761194029852, 61.76470588235294, 51.06382978723405, 64.33566433566433, 58.18181818181818, 54.47761194029852, 61.76470588235294, 51.06382978723405]
#        MCC 0.578 mean,  0.047 stdev
# [0.645584879547703, 0.576464271181895, 0.537735135859368, 0.6106158669217993, 0.517475157540299, 0.645584879547703, 0.576464271181895, 0.537735135859368, 0.6106158669217993, 0.517475157540299]
#      AUPRC 69.86 mean,  2.439 stdev
# [73.62808683036228, 70.40159880938216, 67.62978247031734, 70.81789482071781, 66.80184461198542, 73.62808683036228, 70.40159880938216, 67.62978247031734, 70.81789482071781, 66.80184461198542]
#      AUROC 91.50 mean,  0.552 stdev
# [91.96398939518207, 92.26432525049943, 90.79823682628732, 91.02478558757954, 91.44430950728662, 91.96398939518207, 92.26432525049943, 90.79823682628732, 91.02478558757954, 91.44430950728662]

# %%
if True:   # just to be sure
    print('Rebalance (sample down the majority class) and repeat')
    dataset_cyto,dataset_nuc = rebalance(dataset_cyto,dataset_nuc)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Streaming output truncated to the last 5000 lines.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 1421 355
# Train
# [LightGBM] [Info] Number of positive: 716, number of negative: 705
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031356 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 340126
# [LightGBM] [Info] Number of data points in the train set: 1421, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503871 -> initscore=0.015482
# [LightGBM] [Info] Start training from score 0.015482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 1421 355
# Train
# [LightGBM] [Info] Number of positive: 719, number of negative: 702
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.031847 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 340060
# [LightGBM] [Info] Number of data points in the train set: 1421, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.505982 -> initscore=0.023928
# [LightGBM] [Info] Start training from score 0.023928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Validate
#
# Cross validation results
#   accuracy 82.83 mean,  1.777 stdev
# [80.6179775280899, 82.8169014084507, 81.69014084507043, 83.09859154929578, 85.91549295774648, 80.6179775280899, 82.8169014084507, 81.69014084507043, 83.09859154929578, 85.91549295774648]
#  precision 83.18 mean,  2.960 stdev
# [82.06521739130434, 82.41758241758241, 81.00558659217877, 81.3953488372093, 89.01734104046243, 82.06521739130434, 82.41758241758241, 81.00558659217877, 81.3953488372093, 89.01734104046243]
#     recall 82.70 mean,  1.078 stdev
# [80.74866310160428, 83.79888268156425, 82.38636363636364, 83.33333333333334, 83.24324324324324, 80.74866310160428, 83.79888268156425, 82.38636363636364, 83.33333333333334, 83.24324324324324]
#         F1 82.92 mean,  1.665 stdev
# [81.40161725067384, 83.10249307479224, 81.69014084507042, 82.35294117647058, 86.03351955307264, 81.40161725067384, 83.10249307479224, 81.69014084507042, 82.35294117647058, 86.03351955307264]
#        MCC 0.657 mean,  0.036 stdev
# [0.6117849487477167, 0.65635817888627, 0.633919502285424, 0.6615788802187487, 0.720255615480451, 0.6117849487477167, 0.65635817888627, 0.633919502285424, 0.6615788802187487, 0.720255615480451]
#      AUPRC 90.60 mean,  1.563 stdev
# [90.4738027882195, 92.24679543571854, 88.6575914693069, 89.12464454712574, 92.48193375333243, 90.4738027882195, 92.24679543571854, 88.6575914693069, 89.12464454712574, 92.48193375333243]
#      AUROC 90.35 mean,  1.415 stdev
# [89.0137012308958, 91.80104113763332, 88.9379126460132, 89.72498090145149, 92.28298887122418, 89.0137012308958, 91.80104113763332, 88.9379126460132, 89.72498090145149, 92.28298887122418]

# %%
if True:
    print('Use our lncATLAS training set "all" (-inf <= CN-RCI <= +inf)')
    cyto_f = DATA_DIR+'ForRNAlight.mRNA_RCIgt-1.canonical.tsv'
    nuc_f  = DATA_DIR+'ForRNAlight.mRNA_RCIlt-1.canonical.tsv'
    print(cyto_f,'\n',nuc_f)
    dataset_cyto,dataset_nuc = load_dataframe(cyto_f,nuc_f)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Use our lncATLAS training set "all" (-inf <= CN-RCI <= +inf)
# /content/drive/My Drive/data/Localization/RNAlight/ForRNAlight.mRNA_RCIgt-1.canonical.tsv
#  /content/drive/My Drive/data/Localization/RNAlight/ForRNAlight.mRNA_RCIlt-1.canonical.tsv
# load dataframe
# 12763 cytoplasmic samples
# 3330 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (14483, 1344)
# train set labels [0 1] counts [11512  2971]
# test set labels [0 1] counts [1251  359]
# Round 1 Fold 1
# Num samples in train and valid sets: 11586 2897
# Train
# [LightGBM] [Info] Number of positive: 2368, number of negative: 9218
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.315686 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11586, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.204385 -> initscore=-1.359112
# [LightGBM] [Info] Start training from score -1.359112
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 11586 2897
# Train
# [LightGBM] [Info] Number of positive: 2423, number of negative: 9163
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.361798 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11586, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.209132 -> initscore=-1.330167
# [LightGBM] [Info] Start training from score -1.330167
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 11586 2897
# Train
# [LightGBM] [Info] Number of positive: 2336, number of negative: 9250
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.326616 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11586, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.201623 -> initscore=-1.376183
# [LightGBM] [Info] Start training from score -1.376183
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 11587 2896
# Train
# [LightGBM] [Info] Number of positive: 2395, number of negative: 9192
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.330310 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11587, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206697 -> initscore=-1.344950
# [LightGBM] [Info] Start training from score -1.344950
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 11587 2896
# Train
# [LightGBM] [Info] Number of positive: 2362, number of negative: 9225
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.333128 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11587, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.203849 -> initscore=-1.362408
# [LightGBM] [Info] Start training from score -1.362408
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 11586 2897
# Train
# [LightGBM] [Info] Number of positive: 2368, number of negative: 9218
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.346584 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11586, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.204385 -> initscore=-1.359112
# [LightGBM] [Info] Start training from score -1.359112
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 11586 2897
# Train
# [LightGBM] [Info] Number of positive: 2423, number of negative: 9163
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.339558 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11586, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.209132 -> initscore=-1.330167
# [LightGBM] [Info] Start training from score -1.330167
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 11586 2897
# Train
# [LightGBM] [Info] Number of positive: 2336, number of negative: 9250
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.344005 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11586, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.201623 -> initscore=-1.376183
# [LightGBM] [Info] Start training from score -1.376183
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 11587 2896
# Train
# [LightGBM] [Info] Number of positive: 2395, number of negative: 9192
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.324828 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11587, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.206697 -> initscore=-1.344950
# [LightGBM] [Info] Start training from score -1.344950
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 11587 2896
# Train
# [LightGBM] [Info] Number of positive: 2362, number of negative: 9225
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.335808 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 11587, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.203849 -> initscore=-1.362408
# [LightGBM] [Info] Start training from score -1.362408
# Validate
#
# Cross validation results
#   accuracy 82.86 mean,  0.863 stdev
# [82.94787711425613, 83.84535726613738, 81.53261995167415, 83.6671270718232, 82.28591160220995, 82.94787711425613, 83.84535726613738, 81.53261995167415, 83.6671270718232, 82.28591160220995]
#  precision 67.70 mean,  2.152 stdev
# [70.4119850187266, 63.98601398601399, 68.93939393939394, 67.109634551495, 68.04511278195488, 70.4119850187266, 63.98601398601399, 68.93939393939394, 67.109634551495, 68.04511278195488]
#     recall 31.60 mean,  2.350 stdev
# [31.17744610281924, 33.394160583941606, 28.661417322834648, 35.06944444444444, 29.720853858784896, 31.17744610281924, 33.394160583941606, 28.661417322834648, 35.06944444444444, 29.720853858784896]
#         F1 43.01 mean,  1.959 stdev
# [43.2183908045977, 43.884892086330936, 40.48943270300334, 46.06613454960091, 41.371428571428574, 43.2183908045977, 43.884892086330936, 40.48943270300334, 46.06613454960091, 41.371428571428574]
#        MCC 0.380 mean,  0.015 stdev
# [0.3892506570463359, 0.3808753124888885, 0.35989518376407037, 0.40288869833435303, 0.36691582351788443, 0.3892506570463359, 0.3808753124888885, 0.35989518376407037, 0.40288869833435303, 0.36691582351788443]
#      AUPRC 56.34 mean,  1.085 stdev
# [56.436180043779146, 55.61557484957714, 57.97092903533307, 54.79344375358662, 56.8861968667007, 56.436180043779146, 55.61557484957714, 57.97092903533307, 54.79344375358662, 56.8861968667007]
#      AUROC 81.25 mean,  0.596 stdev
# [80.97712541622026, 82.0201483470214, 81.8732638526285, 80.94041846264368, 80.46131378685696, 80.97712541622026, 82.0201483470214, 81.8732638526285, 80.94041846264368, 80.46131378685696]

# %%
if True:
    print('Rebalance (sample down the majority class) and repeat')
    dataset_cyto,dataset_nuc = rebalance(dataset_cyto,dataset_nuc)
    x_train, x_test, y_train, y_test = extract_features_and_split(dataset_cyto,dataset_nuc)
    stats = do_cv(x_train, y_train)
    print('\nCross validation results')
    stats.dump_all()
# Out:
# Rebalance (sample down the majority class) and repeat
# sample down to balance classes
# 3330 cytoplasmic samples
# 3330 nuclear samples
# add labels, concatenate
# dedupe (probably not necessary)
# count kmers
# train/test split
# train set shape (5994, 1344)
# train set labels [0 1] counts [2995 2999]
# test set labels [0 1] counts [335 331]
# Round 1 Fold 1
# Num samples in train and valid sets: 4795 1199
# Train
# [LightGBM] [Info] Number of positive: 2385, number of negative: 2410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.126324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4795, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497393 -> initscore=-0.010428
# [LightGBM] [Info] Start training from score -0.010428
# Validate
# Round 1 Fold 2
# Num samples in train and valid sets: 4795 1199
# Train
# [LightGBM] [Info] Number of positive: 2412, number of negative: 2383
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.147992 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4795, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503024 -> initscore=0.012096
# [LightGBM] [Info] Start training from score 0.012096
# Validate
# Round 1 Fold 3
# Num samples in train and valid sets: 4795 1199
# Train
# [LightGBM] [Info] Number of positive: 2376, number of negative: 2419
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.156554 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4795, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495516 -> initscore=-0.017936
# [LightGBM] [Info] Start training from score -0.017936
# Validate
# Round 1 Fold 4
# Num samples in train and valid sets: 4795 1199
# Train
# [LightGBM] [Info] Number of positive: 2419, number of negative: 2376
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145100 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4795, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504484 -> initscore=0.017936
# [LightGBM] [Info] Start training from score 0.017936
# Validate
# Round 1 Fold 5
# Num samples in train and valid sets: 4796 1198
# Train
# [LightGBM] [Info] Number of positive: 2404, number of negative: 2392
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.153466 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4796, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501251 -> initscore=0.005004
# [LightGBM] [Info] Start training from score 0.005004
# Validate
# Round 2 Fold 1
# Num samples in train and valid sets: 4795 1199
# Train
# [LightGBM] [Info] Number of positive: 2385, number of negative: 2410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.152010 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4795, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.497393 -> initscore=-0.010428
# [LightGBM] [Info] Start training from score -0.010428
# Validate
# Round 2 Fold 2
# Num samples in train and valid sets: 4795 1199
# Train
# [LightGBM] [Info] Number of positive: 2412, number of negative: 2383
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.159882 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4795, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503024 -> initscore=0.012096
# [LightGBM] [Info] Start training from score 0.012096
# Validate
# Round 2 Fold 3
# Num samples in train and valid sets: 4795 1199
# Train
# [LightGBM] [Info] Number of positive: 2376, number of negative: 2419
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.144905 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4795, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.495516 -> initscore=-0.017936
# [LightGBM] [Info] Start training from score -0.017936
# Validate
# Round 2 Fold 4
# Num samples in train and valid sets: 4795 1199
# Train
# [LightGBM] [Info] Number of positive: 2419, number of negative: 2376
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.153506 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4795, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.504484 -> initscore=0.017936
# [LightGBM] [Info] Start training from score 0.017936
# Validate
# Round 2 Fold 5
# Num samples in train and valid sets: 4796 1198
# Train
# [LightGBM] [Info] Number of positive: 2404, number of negative: 2392
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.155325 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 342720
# [LightGBM] [Info] Number of data points in the train set: 4796, number of used features: 1344
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501251 -> initscore=0.005004
# [LightGBM] [Info] Start training from score 0.005004
# Validate
#
# Cross validation results
#   accuracy 72.49 mean,  0.808 stdev
# [72.81067556296914, 73.39449541284404, 70.97581317764804, 72.5604670558799, 72.70450751252086, 72.81067556296914, 73.39449541284404, 70.97581317764804, 72.5604670558799, 72.70450751252086]
#  precision 72.09 mean,  0.631 stdev
# [73.07692307692307, 71.75324675324676, 72.28525121555916, 71.16357504215851, 72.18543046357617, 73.07692307692307, 71.75324675324676, 72.28525121555916, 71.16357504215851, 72.18543046357617]
#     recall 73.44 mean,  1.269 stdev
# [74.2671009771987, 75.29812606473595, 71.58908507223114, 72.75862068965517, 73.27731092436974, 74.2671009771987, 75.29812606473595, 71.58908507223114, 72.75862068965517, 73.27731092436974]
#         F1 72.75 mean,  0.732 stdev
# [73.66720516962843, 73.48295926849543, 71.93548387096774, 71.95225916453538, 72.72727272727273, 73.66720516962843, 73.48295926849543, 71.93548387096774, 71.95225916453538, 72.72727272727273]
#        MCC 0.450 mean,  0.017 stdev
# [0.4557390051006223, 0.4687432199335045, 0.4188723011797175, 0.4511218827289635, 0.4541718404785572, 0.4557390051006223, 0.4687432199335045, 0.4188723011797175, 0.4511218827289635, 0.4541718404785572]
#      AUPRC 79.45 mean,  1.086 stdev
# [81.17307483282889, 80.25583216067533, 78.85045529224274, 78.2983691986599, 78.67970451401322, 81.17307483282889, 80.25583216067533, 78.85045529224274, 78.2983691986599, 78.67970451401322]
#      AUROC 80.20 mean,  1.118 stdev
# [80.61499484952253, 82.0230818051241, 78.61517968610666, 79.9997214639853, 79.75444904329892, 80.61499484952253, 82.0230818051241, 78.61517968610666, 79.9997214639853, 79.75444904329892]

# %%
print(datetime.now())
print('Done')
# Out:
# 2024-06-05 00:52:56.428462
# Done
